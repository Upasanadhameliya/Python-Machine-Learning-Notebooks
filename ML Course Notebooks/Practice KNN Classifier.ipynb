# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
df = pd.read_csv('KNN_Project_Data')

# %%
df.head()
# Out:
#           XVPM         GWYH         TRAT        TLLZ         IGGA  \
# 0  1636.670614   817.988525  2565.995189  358.347163   550.417491
# 1  1013.402760   577.587332  2644.141273  280.428203  1161.873391
# 2  1300.035501   820.518697  2025.854469  525.562292   922.206261
# 3  1059.347542  1066.866418   612.000041  480.827789   419.467495
# 4  1018.340526  1313.679056   950.622661  724.742174   843.065903
#
#           HYKR         EDFS        GUUB         MGJM         JHZC  \
# 0  1618.870897  2147.641254  330.727893  1494.878631   845.136088
# 1  2084.107872   853.404981  447.157619  1193.032521   861.081809
# 2  2552.355407   818.676686  845.491492  1968.367513  1647.186291
# 3   685.666983   852.867810  341.664784  1154.391368  1450.935357
# 4  1370.554164   905.469453  658.118202   539.459350  1899.850792
#
#    TARGET CLASS
# 0             0
# 1             1
# 2             1
# 3             0
# 4             0

# %%
sns.pairplot(data=df,hue='TARGET CLASS',palette='Set1')

# %%
scaler = StandardScaler()

# %%
scaler.fit(df.drop(labels=['TARGET CLASS'],axis=1))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
newdf = pd.DataFrame(scaler.transform(df.drop(labels=['TARGET CLASS'],axis=1)),columns=df.columns[:-1])

# %%
newdf.head()
# Out:
#        XVPM      GWYH      TRAT      TLLZ      IGGA      HYKR      EDFS  \
# 0  1.568522 -0.443435  1.619808 -0.958255 -1.128481  0.138336  0.980493
# 1 -0.112376 -1.056574  1.741918 -1.504220  0.640009  1.081552 -1.182663
# 2  0.660647 -0.436981  0.775793  0.213394 -0.053171  2.030872 -1.240707
# 3  0.011533  0.191324 -1.433473 -0.100053 -1.507223 -1.753632 -1.183561
# 4 -0.099059  0.820815 -0.904346  1.609015 -0.282065 -0.365099 -1.095644
#
#        GUUB      MGJM      JHZC
# 0 -0.932794  1.008313 -1.069627
# 1 -0.461864  0.258321 -1.041546
# 2  1.149298  2.184784  0.342811
# 3 -0.888557  0.162310 -0.002793
# 4  0.391419 -1.365603  0.787762

# %%
X_train, X_test, y_train, y_test = train_test_split(newdf, df['TARGET CLASS'], test_size=0.3, random_state=101)

# %%
knn = KNeighborsClassifier(n_neighbors=1)

# %%
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=1, p=2,
#                      weights='uniform')

# %%
pred = knn.predict(X_test)

# %%
print(confusion_matrix(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# [[109  43]
#  [ 41 107]]
#               precision    recall  f1-score   support
#
#            0       0.73      0.72      0.72       152
#            1       0.71      0.72      0.72       148
#
#     accuracy                           0.72       300
#    macro avg       0.72      0.72      0.72       300
# weighted avg       0.72      0.72      0.72       300

# %%
error_values = []
for i in range(1,40):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train,y_train)
    pred = knn.predict(X_test)
    error_values.append(np.mean(pred != y_test))

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(12,8))
plt.plot(list(range(1,40)),error_values,ls='--',color='purple',markersize=10,marker='o',markerfacecolor='yellow')

# %%
knn = KNeighborsClassifier(n_neighbors=31)
knn.fit(X_train,y_train)
pred = knn.predict(X_test)
print(confusion_matrix(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# [[123  29]
#  [ 19 129]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.81      0.84       152
#            1       0.82      0.87      0.84       148
#
#     accuracy                           0.84       300
#    macro avg       0.84      0.84      0.84       300
# weighted avg       0.84      0.84      0.84       300
